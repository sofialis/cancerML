# %%
import numpy as np

# %%
def init_data_UCEC(np_data):
    # age 
    age = np_data[:,2].astype(int)

    # clinical_stage
    clinical_stage = np_data[:,4]
    clinical_stage = np.where(clinical_stage=="Stage I", 0, clinical_stage)
    clinical_stage = np.where(clinical_stage=="Stage IA", 1, clinical_stage)
    clinical_stage = np.where(clinical_stage=="Stage IB", 2, clinical_stage)
    clinical_stage = np.where(clinical_stage=="Stage IC", 3, clinical_stage)
    clinical_stage = np.where(clinical_stage=="Stage II", 4, clinical_stage)
    clinical_stage = np.where(clinical_stage=="Stage IIA", 5, clinical_stage)
    clinical_stage = np.where(clinical_stage=="Stage IIB", 6, clinical_stage)
    clinical_stage = np.where(clinical_stage=="Stage III", 7, clinical_stage)
    clinical_stage = np.where(clinical_stage=="Stage IIIA", 8, clinical_stage)
    clinical_stage = np.where(clinical_stage=="Stage IIIB", 9, clinical_stage)
    clinical_stage = np.where(clinical_stage=="Stage IIIC", 10, clinical_stage)
    clinical_stage = np.where(clinical_stage=="Stage IIIC1", 11, clinical_stage)
    clinical_stage = np.where(clinical_stage=="Stage IIIC2", 12, clinical_stage)
    clinical_stage = np.where(clinical_stage=="Stage IV", 13, clinical_stage)
    clinical_stage = np.where(clinical_stage=="Stage IVA", 14, clinical_stage)
    clinical_stage = np.where(clinical_stage=="Stage IVB", 15, clinical_stage)

    # histological_type
    histological_type = np_data[:,5]
    histological_type = np.where(histological_type=="Endometrioid endometrial adenocarcinoma", 1, histological_type)
    histological_type = np.where(histological_type=="Mixed serous and endometrioid", 2, histological_type)
    histological_type = np.where(histological_type=="Serous endometrial adenocarcinoma", 3, histological_type)

    # histological_grade
    histological_grade = np_data[:,6] 
    histological_grade = np.where(histological_grade=="G1", 0, histological_grade)
    histological_grade = np.where(histological_grade=="G2", 1, histological_grade)
    histological_grade = np.where(histological_grade=="G3", 2, 3)

    # initial_pathologic_dx_year
    initial_pathologic_dx_year = np_data[:,7].astype(int)

    # menopause_status

    # vital_status
    vital_status = np_data[:,9]
    vital_status = np.array([l == 'Alive' for l in vital_status]).astype('int') #0 Dead, 1 Alive

    # tumor_status
    tumor_status = np_data[:,10] 
    tumor_status = np.array([l == 'WITH TUMOR' for l in tumor_status]).astype('int') #0 no tum, 1 with tum

    # death_days_to
    death_days_to = np_data[:, 11] 

    # new_tumor_event_type
    new_tumor_event_type = np_data[:,12] # N/A - 0, other - 1
    new_tumor_event_type = np.array([l != '#N/A' for l in new_tumor_event_type]).astype('int') #0 no tum, 1 with tum

    # new_tumor_event_site

    #new_tumor_event_site_other

    #new_tumor_event_dx_days_to
    new_tumor_event_dx_days_to = np_data[:,15]
    new_tumor_event_dx_days_to = np.where(new_tumor_event_dx_days_to=="#N/A", 0 , new_tumor_event_dx_days_to).astype(int)

    # treatment_outcome_first_course

    outcome = np_data[:,16];
    outcome = np.where(outcome=="Complete Remission/Response", 0, outcome)
    outcome = np.where(outcome=="Partial Remission/Response", 3, outcome)
    outcome = np.where(outcome=="Progressive Disease", 2, outcome)
    outcome = np.where(outcome=="Stable Disease", 1, outcome)
    outcome = np.where(outcome=="Persistent Disease", 4, outcome)

    m = np_data.shape[0]
    X = np.stack([np.ones(m), age, histological_grade, histological_type, clinical_stage, initial_pathologic_dx_year, tumor_status, new_tumor_event_type, new_tumor_event_dx_days_to], axis=1).astype(int)
    feature_labels = ['1-vector', 'age', 'histological_grade', 'histological_type', 'clinical_stage', 'initial_pathologic_dx_year', 'tumor_status', 'new_tumor_event_type', 'new_tumor_event_dx_days_to']
    return X, feature_labels, vital_status, death_days_to, outcome

# %%
def init_data_STAD(np_data):
    # age 
    age = np_data[:,2].astype(int)

    # gender
    gender = np_data[:,3]
    gender = np.array([l == 'FEMALE' for l in gender]).astype('int') #0 man, 1 woman

    # ajcc_pathologic_tumor_stage
    tumor_stage = np_data[:,4]

    tumor_stage = np.where(tumor_stage=="Stage I", 1, tumor_stage)
    tumor_stage = np.where(tumor_stage=="Stage IA", 2, tumor_stage)
    tumor_stage = np.where(tumor_stage=="Stage IB", 3, tumor_stage)
    tumor_stage = np.where(tumor_stage=="Stage II", 4, tumor_stage)
    tumor_stage = np.where(tumor_stage=="Stage IIA", 5, tumor_stage)
    tumor_stage = np.where(tumor_stage=="Stage IIB", 6, tumor_stage)
    tumor_stage = np.where(tumor_stage=="Stage III", 7, tumor_stage)
    tumor_stage = np.where(tumor_stage=="Stage IIIA", 8, tumor_stage)
    tumor_stage = np.where(tumor_stage=="Stage IIIB", 9, tumor_stage)
    tumor_stage = np.where(tumor_stage=="Stage IIIC", 10, tumor_stage)
    tumor_stage = np.where(tumor_stage=="Stage IV", 11, tumor_stage)

    # histological_type
    histological_type = np_data[:,5]
    histological_type = np.where(histological_type=="Stomach Adenocarcinoma, Signet Ring Type", 1, histological_type)
    histological_type = np.where(histological_type=="Stomach, Adenocarcinoma, Diffuse Type", 2, histological_type)
    histological_type = np.where(histological_type=="Stomach, Adenocarcinoma, Not Otherwise Specified (NOS)", 3, histological_type)
    histological_type = np.where(histological_type=="Stomach, Intestinal Adenocarcinoma, Mucinous Type", 4, histological_type)
    histological_type = np.where(histological_type=="Stomach, Intestinal Adenocarcinoma, Not Otherwise Specified (NOS)", 5, histological_type)
    histological_type = np.where(histological_type=="Stomach, Intestinal Adenocarcinoma, Papillary Type", 6, histological_type)
    histological_type = np.where(histological_type=="Stomach, Intestinal Adenocarcinoma, Tubular Type", 7, histological_type)

    # histological_grade
    histological_grade = np_data[:,6] 
    histological_grade = np.where(histological_grade=="G1", 0, histological_grade)
    histological_grade = np.where(histological_grade=="G2", 1, histological_grade)
    histological_grade = np.where(histological_grade=="G3", 2, 3)

    # initial_pathologic_dx_year
    initial_pathologic_dx_year = np_data[:,7].astype(int)

    # vital_status
    vital_status = np_data[:,8]
    vital_status = np.array([l == 'Alive' for l in vital_status]).astype('int') #0 Dead, 1 Alive

    # tumor_status
    tumor_status = np_data[:,9] 
    tumor_status = np.array([l == 'WITH TUMOR' for l in tumor_status]).astype('int') #0 no tum, 1 with tum

    # death_days_to
    death_days_to = np_data[:, 10] 

    # new_tumor_event_type
    new_tumor_event_type = np_data[:,11] # N/A - 0, other - 1
    new_tumor_event_type = np.array([l != '#N/A' for l in new_tumor_event_type]).astype('int') #0 no tum, 1 with tum

    # new_tumor_event_site	new_tumor_event_site_other

    #new_tumor_event_dx_days_to
    new_tumor_event_dx_days_to = np_data[:,14]
    new_tumor_event_dx_days_to = np.where(new_tumor_event_dx_days_to=="#N/A", 0 , new_tumor_event_dx_days_to).astype(int)

    #treatment_outcome_first_course
    outcome = np_data[:,15];
    outcome = np.where(outcome=="Complete Remission/Response", 0, outcome)
    outcome = np.where(outcome=="Partial Remission/Response", 3, outcome)
    outcome = np.where(outcome=="Progressive Disease", 2, outcome)
    outcome = np.where(outcome=="Stable Disease", 1, outcome)

    m = np_data.shape[0]
    X = np.stack([np.ones(m), age, gender, tumor_stage, histological_grade, histological_type, initial_pathologic_dx_year, tumor_status, new_tumor_event_type, new_tumor_event_dx_days_to], axis=1).astype(int)
    feature_labels = ['1-vector', 'age', 'gender', 'tumor_stage', 'histological_grade', 'histological_type', 'initial_pathologic_dx_year', 'tumor_status', 'new_tumor_event_type', 'new_tumor_event_dx_days_to']
    return X, feature_labels, vital_status, death_days_to, outcome

# %%
def init_data_OV(np_data):
    # age 
    age = np_data[:,2].astype(int)

    # gender
    gender = np_data[:,3]
    gender = np.array([l == 'FEMALE' for l in gender]).astype('int') #0 man, 1 woman

    # ajcc_pathologic_tumor_stage
    clinical_stage = np_data[:,4]
    # clinical_stage = np.where(clinical_stage=="Stage I", 0, clinical_stage)
    clinical_stage = np.where(clinical_stage=="Stage IA", 1, clinical_stage)
    clinical_stage = np.where(clinical_stage=="Stage IB", 2, clinical_stage)
    clinical_stage = np.where(clinical_stage=="Stage IC", 3, clinical_stage)
    clinical_stage = np.where(clinical_stage=="Stage IIA", 4, clinical_stage)
    clinical_stage = np.where(clinical_stage=="Stage IIB", 5, clinical_stage)
    clinical_stage = np.where(clinical_stage=="Stage IIC", 6, clinical_stage)
    clinical_stage = np.where(clinical_stage=="Stage IIIA", 7, clinical_stage)
    clinical_stage = np.where(clinical_stage=="Stage IIIB", 8, clinical_stage)
    clinical_stage = np.where(clinical_stage=="Stage IIIC", 9, clinical_stage)
    clinical_stage = np.where(clinical_stage=="Stage IV", 10, clinical_stage)

    # histological_type
    histological_type = np_data[:,5] # ignore, they are all the same

    # histological_grade
    histological_grade = np_data[:,6] 
    histological_grade = np.where(histological_grade=="G1", 0, histological_grade)
    histological_grade = np.where(histological_grade=="G2", 1, histological_grade)
    histological_grade = np.where(histological_grade=="G3", 2, 3)

    # initial_pathologic_dx_year
    initial_pathologic_dx_year = np_data[:,7].astype(int)

    # vital_status
    vital_status = np_data[:,8]
    vital_status = np.array([l == 'Alive' for l in vital_status]).astype('int') #0 Dead, 1 Alive

    # tumor_status
    tumor_status = np_data[:,9] 
    tumor_status = np.array([l == 'WITH TUMOR' for l in tumor_status]).astype('int') #0 no tum, 1 with tum

    # death_days_to
    death_days_to = np_data[:, 10] 

    # new_tumor_event_type
    new_tumor_event_type = np_data[:,11] # N/A - 0, other - 1
    new_tumor_event_type = np.array([l != '#N/A' for l in new_tumor_event_type]).astype('int') #0 no tum, 1 with tum

    #new_tumor_event_dx_days_to
    new_tumor_event_dx_days_to = np_data[:,12]
    new_tumor_event_dx_days_to = np.where(new_tumor_event_dx_days_to=="#N/A", 0 , new_tumor_event_dx_days_to).astype(int)

    #treatment_outcome_first_course
    outcome = np_data[:,13];
    outcome = np.where(outcome=="Complete Remission/Response", 0, outcome)
    outcome = np.where(outcome=="Partial Remission/Response", 3, outcome)
    outcome = np.where(outcome=="Progressive Disease", 2, outcome)
    outcome = np.where(outcome=="Stable Disease", 1, outcome)

    m = np_data.shape[0]
    X = np.stack([np.ones(m), age, gender, clinical_stage, histological_grade, initial_pathologic_dx_year, tumor_status, new_tumor_event_type, new_tumor_event_dx_days_to], axis=1).astype(int)
    feature_labels = ['1-vector', 'age', 'gender', 'clinical_stage', 'histological_grade', 'initial_pathologic_dx_year', 'tumor_status', 'new_tumor_event_type', 'new_tumor_event_dx_days_to']
    return X, feature_labels, vital_status, death_days_to, outcome

# %%
def init_data_LUSC(np_data):
    # age 
    age = np_data[:,2].astype(int)

    # gender
    gender = np_data[:,3]
    gender = np.array([l == 'FEMALE' for l in gender]).astype('int') #0 man, 1 woman

    # ajcc_pathologic_tumor_stage
    tumor_stage = np_data[:,4]
    tumor_stage = np.where(tumor_stage=="Stage I", 0, tumor_stage)
    tumor_stage = np.where(tumor_stage=="Stage IA", 0, tumor_stage)
    tumor_stage = np.where(tumor_stage=="Stage IB", 1, tumor_stage)
    tumor_stage = np.where(tumor_stage=="Stage II", 2, tumor_stage)
    tumor_stage = np.where(tumor_stage=="Stage IIA", 2, tumor_stage)
    tumor_stage = np.where(tumor_stage=="Stage IIB", 3, tumor_stage)
    tumor_stage = np.where(tumor_stage=="Stage IIIA", 4, tumor_stage)
    tumor_stage = np.where(tumor_stage=="Stage IIIB", 5, tumor_stage)
    tumor_stage = np.where(tumor_stage=="Stage IV", 6, tumor_stage)

    # histological_type
    histological_type = np_data[:,5] # ignore, they are all the same

    # initial_pathologic_dx_year
    initial_pathologic_dx_year = np_data[:,6].astype(int)

    # vital_status
    vital_status = np_data[:,7]
    vital_status = np.array([l == 'Alive' for l in vital_status]).astype('int') #0 Dead, 1 Alive

    # tumor_status
    tumor_status = np_data[:,8] 
    tumor_status = np.array([l == 'WITH TUMOR' for l in tumor_status]).astype('int') #0 no tum, 1 with tum

    # death_days_to
    death_days_to = np_data[:, 9] 

    # new_tumor_event_type
    new_tumor_event_type = np_data[:,10] # N/A - 0, other - 1
    new_tumor_event_type = np.array([l != '#N/A' for l in new_tumor_event_type]).astype('int') #0 no tum, 1 with tum

    #new_tumor_event_dx_days_to
    new_tumor_event_dx_days_to = np_data[:,11]
    new_tumor_event_dx_days_to = np.where(new_tumor_event_dx_days_to=="#N/A", 0 , new_tumor_event_dx_days_to).astype(int)

    #treatment_outcome_first_course
    outcome = np_data[:,12];
    outcome = np.where(outcome=="Complete Remission/Response", 0, outcome)
    outcome = np.where(outcome=="Partial Remission/Response", 3, outcome)
    outcome = np.where(outcome=="Progressive Disease", 2, outcome)
    outcome = np.where(outcome=="Stable Disease", 1, outcome)

    m = np_data.shape[0]
    X = np.stack([np.ones(m), age, gender, tumor_stage, initial_pathologic_dx_year, tumor_status, new_tumor_event_type, new_tumor_event_dx_days_to], axis=1).astype(int)
    feature_labels = ['1-vector', 'age', 'gender', 'tumor_stage', 'initial_pathologic_dx_year', 'tumor_status', 'new_tumor_event_type', 'new_tumor_event_dx_days_to']
    return X, feature_labels, vital_status, death_days_to, outcome

# %%
def init_data_LUAD(np_data):
    # age 
    age = np_data[:,2].astype(int)

    # gender
    gender = np_data[:,3]
    gender = np.array([l == 'FEMALE' for l in gender]).astype('int') #0 man, 1 woman

    # ajcc_pathologic_tumor_stage
    tumor_stage = np_data[:,4]
    tumor_stage = np.where(tumor_stage=="Stage I", 0, tumor_stage)
    tumor_stage = np.where(tumor_stage=="Stage IA", 0, tumor_stage)
    tumor_stage = np.where(tumor_stage=="Stage IB", 1, tumor_stage)
    tumor_stage = np.where(tumor_stage=="Stage II", 2, tumor_stage)
    tumor_stage = np.where(tumor_stage=="Stage IIA", 2, tumor_stage)
    tumor_stage = np.where(tumor_stage=="Stage IIB", 3, tumor_stage)
    tumor_stage = np.where(tumor_stage=="Stage IIIA", 4, tumor_stage)
    tumor_stage = np.where(tumor_stage=="Stage IIIB", 5, tumor_stage)
    tumor_stage = np.where(tumor_stage=="Stage IV", 6, tumor_stage)

    # histological_type
    histological_type = np_data[:,5] # ignore, they are all the same

    # initial_pathologic_dx_year
    initial_pathologic_dx_year = np_data[:,6].astype(int)

    # vital_status
    vital_status = np_data[:,7]
    vital_status = np.array([l == 'Alive' for l in vital_status]).astype('int') #0 Dead, 1 Alive

    # tumor_status
    tumor_status = np_data[:,8] 
    tumor_status = np.array([l == 'WITH TUMOR' for l in tumor_status]).astype('int') #0 no tum, 1 with tum

    # death_days_to
    death_days_to = np_data[:, 9] 

    # new_tumor_event_type
    new_tumor_event_type = np_data[:,10] # N/A - 0, other - 1
    new_tumor_event_type = np.array([l != '#N/A' for l in new_tumor_event_type]).astype('int') #0 no tum, 1 with tum

    #new_tumor_event_dx_days_to
    new_tumor_event_dx_days_to = np_data[:,11]
    new_tumor_event_dx_days_to = np.where(new_tumor_event_dx_days_to=="#N/A", 0 , new_tumor_event_dx_days_to).astype(int)

    #treatment_outcome_first_course
    outcome = np_data[:,12];
    outcome = np.where(outcome=="Complete Remission/Response", 0, outcome)
    outcome = np.where(outcome=="Partial Remission/Response", 3, outcome)
    outcome = np.where(outcome=="Progressive Disease", 2, outcome)
    outcome = np.where(outcome=="Stable Disease", 1, outcome)

    m = np_data.shape[0]
    X = np.stack([np.ones(m), age, gender, tumor_stage, initial_pathologic_dx_year, tumor_status, new_tumor_event_type, new_tumor_event_dx_days_to], axis=1).astype(int)
    feature_labels = ['1-vector', 'age', 'gender', 'tumor_stage', 'initial_pathologic_dx_year', 'tumor_status', 'new_tumor_event_type', 'new_tumor_event_dx_days_to']
    return X, feature_labels, vital_status, death_days_to, outcome

# %%
def init_data_LGG(np_data):
    # age 
    age = np_data[:,2].astype(int)

    # gender
    gender = np_data[:,3]
    gender = np.array([l == 'FEMALE' for l in gender]).astype('int') #0 man, 1 woman

    # histological_type
    histological_type = np_data[:,4]
    histological_type = np.where(histological_type=="Astrocytoma", 0, histological_type)
    histological_type = np.where(histological_type=="Oligoastrocytoma", 1, histological_type)
    histological_type = np.where(histological_type=="Oligodendroglioma", 2, histological_type)

    # histological_grade
    histological_grade = np_data[:,5] 
    histological_grade = np.where(histological_grade=="G2", 0, histological_grade)
    histological_grade = np.where(histological_grade=="G3", 1, histological_grade)

    # initial_pathologic_dx_year
    initial_pathologic_dx_year = np_data[:,6].astype(int)

    # vital_status
    vital_status = np_data[:,7]
    vital_status = np.array([l == 'Alive' for l in vital_status]).astype('int') #0 Dead, 1 Alive

    # tumor_status
    tumor_status = np_data[:,8] 
    tumor_status = np.array([l == 'WITH TUMOR' for l in tumor_status]).astype('int') #0 no tum, 1 with tum

    # death_days_to
    death_days_to = np_data[:, 9] 

    #new_tumor_event_dx_days_to
    new_tumor_event_dx_days_to = np_data[:,10]
    new_tumor_event_dx_days_to = np.where(new_tumor_event_dx_days_to=="#N/A", 0 , new_tumor_event_dx_days_to).astype(int)


    #treatment_outcome_first_course
    outcome = np_data[:,11];
    outcome = np.where(outcome=="Complete Remission/Response", 0, outcome)
    outcome = np.where(outcome=="Partial Remission/Response", 1, outcome)
    outcome = np.where(outcome=="Progressive Disease", 2, outcome)
    outcome = np.where(outcome=="Stable Disease", 3, outcome)

    m = np_data.shape[0]
    X = np.stack([np.ones(m), age, gender, histological_grade,histological_type, initial_pathologic_dx_year, tumor_status, new_tumor_event_dx_days_to], axis=1).astype(int)
    feature_labels = ['1-vector', 'age', 'gender', 'histological_grade','histological_type', 'initial_pathologic_dx_year', 'tumor_status', 'new_tumor_event_dx_days_to']
    return X, feature_labels, vital_status, death_days_to, outcome

# %%
def init_data_BLCA(np_data):
    # age 
    age = np_data[:,2].astype(int)

    # gender
    gender = np_data[:,3]
    gender = np.array([l == 'FEMALE' for l in gender]).astype('int') #0 man, 1 woman

    # ajcc_pathologic_tumor_stage
    tumor_stage = np_data[:,4]
    tumor_stage = np.where(tumor_stage=="Stage I", 0, tumor_stage)
    tumor_stage = np.where(tumor_stage=="Stage II", 1, tumor_stage)
    tumor_stage = np.where(tumor_stage=="Stage III", 2, tumor_stage)
    tumor_stage = np.where(tumor_stage=="Stage IV", 3, tumor_stage)

    # initial_pathologic_dx_year
    initial_pathologic_dx_year = np_data[:,7].astype(int)

    # vital_status
    vital_status = np_data[:,8]
    vital_status = np.array([l == 'Alive' for l in vital_status]).astype('int') #0 Dead, 1 Alive

    # tumor_status
    tumor_status = np_data[:,9] 
    tumor_status = np.array([l == 'WITH TUMOR' for l in tumor_status]).astype('int') #0 no tum, 1 with tum

    # death_days_to
    death_days_to = np_data[:, 10] 

    # new_tumor_event_type
    new_tumor_event_type = np_data[:,11] # N/A - 0, other - 1
    new_tumor_event_type = np.array([l != '#N/A' for l in new_tumor_event_type]).astype('int') #0 no tum, 1 with tum

    # new_tumor_event_site
    new_tumor_event_site = np_data[:,12]
    new_tumor_event_site = np.array([l != '#N/A' for l in new_tumor_event_site]).astype('int') #0 no tum, 1 with tum

    #new_tumor_event_site_other

    #new_tumor_event_dx_days_to
    new_tumor_event_dx_days_to = np_data[:,14]
    new_tumor_event_dx_days_to = np.where(new_tumor_event_dx_days_to=="#N/A", 0 , new_tumor_event_dx_days_to).astype(int)


    #treatment_outcome_first_course
    outcome = np_data[:,15];
    outcome = np.where(outcome=="Complete Remission/Response", 0, outcome)
    outcome = np.where(outcome=="Partial Remission/Response", 3, outcome)
    outcome = np.where(outcome=="Progressive Disease", 2, outcome)
    outcome = np.where(outcome=="Stable Disease", 1, outcome)
    
    m = np_data.shape[0]
    X = np.stack([np.ones(m), age, gender, tumor_stage, initial_pathologic_dx_year, tumor_status, new_tumor_event_type, new_tumor_event_dx_days_to], axis=1).astype(int)
    feature_labels = ['1-vector', 'age', 'gender', 'tumor_stage', 'initial_pathologic_dx_year', 'tumor_status', 'new_tumor_event_type', 'new_tumor_event_dx_days_to']
    return X, feature_labels, vital_status, death_days_to, outcome

# %%
def init_data_HNSC(np_data):
    # age 
    age = np_data[:,2].astype(int)

    # gender
    gender = np_data[:,3]
    gender = np.array([l == 'FEMALE' for l in gender]).astype('int') #0 man, 1 woman

    # ajcc_pathologic_tumor_stage
    tumor_stage = np_data[:,4]
    tumor_stage = np.where(tumor_stage=="Stage I", 0, tumor_stage)
    tumor_stage = np.where(tumor_stage=="Stage II", 1, tumor_stage)
    tumor_stage = np.where(tumor_stage=="Stage III", 2, tumor_stage)
    tumor_stage = np.where(tumor_stage=="Stage IVA", 3, tumor_stage)
    tumor_stage = np.where(tumor_stage=="Stage IVB", 4, tumor_stage)

    # clinical_stage
    clinical_stage = np_data[:,5]
    clinical_stage = np.where(clinical_stage=="Stage I", 0, clinical_stage)
    clinical_stage = np.where(clinical_stage=="Stage II", 1, clinical_stage)
    clinical_stage = np.where(clinical_stage=="Stage III", 2, clinical_stage)
    clinical_stage = np.where(clinical_stage=="Stage IVA", 3, clinical_stage)
    clinical_stage = np.where(clinical_stage=="Stage IVB", 4, clinical_stage)
    clinical_stage = np.where(clinical_stage=="Stage IVC", 5, clinical_stage)

    # histological_type
    histological_type = np_data[:,6] # ignore, they are all the same

    # histological_grade
    histological_grade = np_data[:,7] 
    histological_grade = np.where(histological_grade=="G1", 0, histological_grade)
    histological_grade = np.where(histological_grade=="G2", 1, histological_grade)
    histological_grade = np.where(histological_grade=="G3", 2, histological_grade)
    histological_grade = np.where(histological_grade=="G4", 3, histological_grade)
    histological_grade = np.where(histological_grade=="GX", 4, histological_grade)

    # initial_pathologic_dx_year
    initial_pathologic_dx_year = np_data[:,8].astype(int)

    # vital_status
    vital_status = np_data[:,9]
    vital_status = np.array([l == 'Alive' for l in vital_status]).astype('int') #0 Dead, 1 Alive

    # tumor_status
    tumor_status = np_data[:,10] 
    tumor_status = np.array([l == 'WITH TUMOR' for l in tumor_status]).astype('int') #0 no tum, 1 with tum

    # death_days_to
    death_days_to = np_data[:, 11] 

    # new_tumor_event_type
    new_tumor_event_type = np_data[:,12] # N/A - 0, other - 1
    new_tumor_event_type = np.array([l != '#N/A' for l in new_tumor_event_type]).astype('int') #0 no tum, 1 with tum

    # new_tumor_event_site
    new_tumor_event_site = np_data[:,13]
    new_tumor_event_site = np.array([l != '#N/A' for l in new_tumor_event_site]).astype('int') #0 no tum, 1 with tum

    #new_tumor_event_site_other

    #new_tumor_event_dx_days_to
    new_tumor_event_dx_days_to = np_data[:,15]
    new_tumor_event_dx_days_to = np.where(new_tumor_event_dx_days_to=="#N/A", 0 , new_tumor_event_dx_days_to).astype(int)

    # treatment_outcome_first_course

    outcome = np_data[:,16];
    outcome = np.where(outcome=="Complete Remission/Response", 0, outcome)
    outcome = np.where(outcome=="Partial Remission/Response", 3, outcome)
    outcome = np.where(outcome=="Progressive Disease", 2, outcome)
    outcome = np.where(outcome=="Stable Disease", 1, outcome)
    outcome = np.where(outcome=="Persistent Disease", 4, outcome)
    
    m = np_data.shape[0]
    X = np.stack([np.ones(m), age, gender, tumor_stage, histological_grade, clinical_stage, initial_pathologic_dx_year, tumor_status, new_tumor_event_type, new_tumor_event_dx_days_to], axis=1).astype(int)
    feature_labels = ['1-vector', 'age', 'gender', 'tumor_stage', 'histological_grade', 'clinical_stage', 'initial_pathologic_dx_year', 'tumor_status', 'new_tumor_event_type', 'new_tumor_event_dx_days_t']
    return X, feature_labels, vital_status, death_days_to, outcome
